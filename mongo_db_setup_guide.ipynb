# %% [markdown]
# #### Documentation for connection with MongoDb:

# %%
pip install pymongo[srv]==4.1.1
# Out:
# ...
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 3.6.0
#     Uninstalling pymongo-3.6.0:
#       Successfully uninstalled pymongo-3.6.0
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\anaconda\lib\site-packages)

# %% [markdown]
# #### Getting url:
#
# #### step_1:
# ![image.png](attachment:image.png)
#
# #### step_2:
# ![image-2.png](attachment:image-2.png)
#
#
# #### step_3:
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Resetting the password:
# #### STEP_1
# ![image-2.png](attachment:image-2.png)
#
# #### STEP_2
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Esatablish connection with the server using blank ip address (0.0.0.0/0):
# #### in this case user and password is "root" and "root"
# #### copy the url --> if connect is true then th econnect is established
# ![image.png](attachment:image.png)

# %%
import pymongo
connection_string="mongodb+srv://root:root@cluster0.tafcuyk.mongodb.net/?retryWrites=true&w=majority"

# %%
class mongo:
    def __init__(self):
        self.url=connection_string
        
    def client(self):
        # Send a ping to confirm a successful connection
        try:
            client=pymongo.MongoClient(self.url)
            return client
            print(client,"\n\n You successfully connected to MongoDB!")
        except Exception as e:
            print(e)

# %%
mongo().client()

# %% [markdown]
# ### now connection is established lets roll the query:

# %% [markdown]
# #### Task:1
# > create database original command :
# >>client["database name"]
#
# >insert data into table:
# >> one recoed
#
# >> many record
#
#
# #### check main.py file
